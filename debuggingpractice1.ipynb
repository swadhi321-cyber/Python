# %%
#1.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#2.What will be the output of this code?

a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
    return a + b

# %%
#4.Find the error in the following Python code:

for i in range(5):
     print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#5.Find the error in the following Python code:
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6. Find the error in the following Python code:
x = 10
if x == 5:
    print("x is 5")

# %%
#7. Identify the error in the following function definition:

def greet(name):
    print("Hello" + name)

# %%
#8.What is the issue in this Python snippet?

def add_numbers(a, b):
    return a + b

# %%
#9.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#10.Find the error in the following Python code:name = "Alice"
name = Alice
age = 25
print(f"Name={name}"/n, f'Age={age}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 #10.Find the error in the following Python code:name = "Alice"
# ----> 2 name = Alice
#       3 age = 25
#       4 print(f"Name={name}"/n, f'Age={age}')
#
# NameError: name 'Alice' is not defined
